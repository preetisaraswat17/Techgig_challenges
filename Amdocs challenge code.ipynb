# %%
#from scipy.spatial.distance import pdist
import math
from itertools import repeat
def distance(p1,p2):
    x1,y1=p1
    x2,y2=p2
    return math.hypot(x2-x1,y2-y1)
def main():
    testcases=int(input())
    #print(testcases)
    for i in range(0, testcases):
        L=int(input())
        #print (L)
        shipcoordinates=[]
        for j in range(0, L):
            x = list(map(int, input().split()))
            shipcoordinates.append(x)
        #radius=[]
        for k in range(0, len(shipcoordinates)):
              for l in range (0, len(shipcoordinates)):
                 if (k!=l):
                    r=[distance(*pair) for pair in zip(repeat(shipcoordinates[k]),shipcoordinates[1:])]
                    print(r)
                 else:
                    pass
    
main()

# %%
#from scipy.spatial.distance import pdist
import math
from itertools import repeat
def distance(p1,p2):
    x1,y1=p1
    x2,y2=p2
    return math.hypot(x2-x1,y2-y1)
def main():
    testcases=int(input())
    #print(testcases)
    for i in range(0, testcases):
        L=int(input())
        #print (L)
        shipcoordinates=[]
        for j in range(0, L):
            x = list(map(int, input().split()))
            shipcoordinates.append(x)
        #radius=[]
        for i in range(0, len(shipcoordinates)):
              r=[distance(*pair) for pair in zip(repeat(shipcoordinates[i]),shipcoordinates[1:])]
              print(min(r))
main()

# %%
import math
from itertools import repeat
def distance(p1,p2):
    x1,y1=p1
    x2,y2=p2
    return math.hypot(x2-x1,y2-y1)
def main():
    testcases=int(input())
    #print(testcases)
    for i in range(0, testcases):
        L=int(input())
        #print (L)
        shipcoordinates=[]
        for j in range(0, L):
            x = list(map(int, input().split()))
            shipcoordinates.append(x)
        #radius=[]
        for i in range(0, len(shipcoordinates)):
              #r=[distance(*pair) for pair in zip(repeat(shipcoordinates[i]),shipcoordinates[0:]) if shipcoordinates[i]< shipcoordinates[i+1] else pass]
              r=[distance(*pair) if shipcoordinates[i]< shipcoordinates[i+1] for pair in zip(repeat(shipcoordinates[i]),shipcoordinates[0:])]
              print(r)
main()

# %%
#from scipy.spatial.distance import pdist
import math
from itertools import repeat
def distance(p1,p2):
    x1,y1=p1
    x2,y2=p2
    return math.hypot(x2-x1,y2-y1)
def main():
    testcases=int(input())
    #print(testcases)
    for i in range(0, testcases):
        L=int(input())
        #print (L)
        shipcoordinates=[]
        for j in range(0, L):
            x = list(map(int, input().split()))
            shipcoordinates.append(x)
        #radius=[]
        for m in range(0, len(shipcoordinates)):
             r=[distance(*pair) if shipcoordinates[m]!= shipcoordinates[n] for n in shipcoordinates]
             print(r)
    
main()

# %%
#from scipy.spatial.distance import pdist
import math
#from itertools import repeat
from itertools import combinations
def distance(p1,p2):
    x1,y1=p1
    x2,y2=p2
    return math.hypot(x2-x1,y2-y1)
def main():
    testcases=int(input())
    #print(testcases)
    for i in range(0, testcases):
        L=int(input())
        #print (L)
        shipcoordinates=[]
        for j in range(0, L):
            x = list(map(int, input().split()))
            shipcoordinates.append(x)
        #radius=[]
        for i in range(len(shipcoordinates)):
              r=[distance(*pair) for pair in combinations(shipcoordinates,2)]
              print(r)
             
            
main()

# %%
#from scipy.spatial.distance import pdist
import math
from itertools import repeat
def distance(p1,p2):
    x1,y1=p1
    x2,y2=p2
    return math.hypot(x2-x1,y2-y1)
def main():
    testcases=int(input())
    #print(testcases)
    for i in range(0, testcases):
        L=int(input())
        #print (L)
        shipcoordinates=[]
        for j in range(0, L):
            x = list(map(int, input().split()))
            shipcoordinates.append(x)
        radius=[]
        this_item = shipcoordinates[0]
        for item in shipcoordinates[1:]:
            prev_item = this_item
            this_item = item
            coord_dist = distance(prev_item, this_item)
            radius.append(coord_dist)
        for r in radius[0:]:
             diam=r*2
             count = 0
             if (r <= diam): 
                count = count + 1
             print(r,count)
    
main()

# %%
#from scipy.spatial.distance import pdist
import math
from itertools import repeat
def distance(p1,p2):
    x1,y1=p1
    x2,y2=p2
    return math.hypot(x2-x1,y2-y1)
def main():
    testcases=int(input())
    #print(testcases)
    for i in range(0, testcases):
        L=int(input())
        #print (L)
        shipcoordinates=[]
        for j in range(0, L):
            x = list(map(int, input().split()))
            shipcoordinates.append(x)
        radius=[]
        for item in shipcoordinates[0:]:
          for i in range(0,len(shipcoordinates)):
            this_item = shipcoordinates[i]
            prev_item = this_item
            this_item = item[i]
            coord_dist = distance(prev_item, this_item)
            radius.append(coord_dist)
        for r in radius[0:]:
             diam=r*2
             count = 0
             if (r <= diam): 
                count = count + 1
             print(r,count)
    
main()

# %%
#from scipy.spatial.distance import pdist
import math
import decimal
from itertools import repeat
def truncate(number, digits) -> float:
    stepper = pow(10.0, digits)
    return math.trunc(stepper * number) / stepper
def distance(p1,p2):
    x1,y1=p1
    x2,y2=p2
    return math.hypot(x2-x1,y2-y1)
def main():
    testcases=int(input())
    output=[]
    #print(testcases)
    for i in range(0, testcases):
        L=int(input())
        #print (L)
        shipcoordinates=[]
        for j in range(0, L):
            x = list(map(int, input().split()))
            shipcoordinates.append(x)
        for m in range(0,len(shipcoordinates)):
            pOne = shipcoordinates[m]
            radius=[]
            
            for item in range(0,len(shipcoordinates)):
                 if (m!=item):
                     #print('pOne',pOne)
                     pTwo = shipcoordinates[item]
                     #print('pTwo',pTwo )
                     #coordDist = truncate(distance(pOne,pTwo),2)
                     coordDist = distance(pOne,pTwo)
                     #print('coordDist',coordDist )
                     radius.append(coordDist)
            #effdist=decimal.Decimal(min(radius)).quantize(decimal.Decimal(".01"))
            effdist=min(radius)
            count = 0
            diam=effdist*2
            #print ('effdist',effdist)
            #print ('diam',diam)
            for r in radius[0:]:
                        if (r <= diam): 
                           #print(r)
                           count = count + 1
            final=decimal.Decimal(effdist).quantize(decimal.Decimal(".01"))
            output.append(final,count)
    for item in output:
        print  (item[0]," ".join(map(str, item[1:])))

    
main()

# %%
#from scipy.spatial.distance import pdist
import math
import decimal

from itertools import repeat
def distance(p1,p2):
    x1,y1=p1
    x2,y2=p2
    return math.hypot(x2-x1,y2-y1)
def main():
    testcases=int(input())
    output=[]
    #print(testcases)
    for i in range(0, testcases):
        L=int(input())
        #print (L)
        shipcoordinates=[]
        for j in range(0, L):
            x = list(map(int, input().split()))
            shipcoordinates.append(x)
        for m in range(0,len(shipcoordinates)):
            pOne = shipcoordinates[m]
            radius=[]
            #print('pTwo',pTwo )
            for item in range(0,len(shipcoordinates)):
                 if (m!=item):
                     #print('pOne',pOne)
                     pTwo = shipcoordinates[item]
                     #print('pTwo',pTwo )
                     coordDist = round(distance(pOne,pTwo),2)
                     #print('coordDist',coordDist )
                     radius.append(coordDist)
            effdist=decimal.Decimal(min(radius)).quantize(decimal.Decimal(".01"))
            count = 0
            diam=effdist*2
            for r in radius[0:]:
                        if (r < diam): 
                           count = count + 1
            output.append((effdist,count))
    for item in output:
        print  (item[0].join(map(str, item[1:])))

    
main()

# %%
#from scipy.spatial.distance import pdist
import math
import decimal

from itertools import repeat
def distance(p1,p2):
    x1,y1=p1
    x2,y2=p2
    return math.hypot(x2-x1,y2-y1)
def main():
    testcases=int(input())
    output=[]
    #print(testcases)
    for i in range(0, testcases):
        L=int(input())
        #print (L)
        shipcoordinates=[]
        for j in range(0, L):
            x = list(map(int, input().split()))
            shipcoordinates.append(x)
        for m in range(0,len(shipcoordinates)):
            pOne = shipcoordinates[m]
            radius=[]
            
            for item in range(0,len(shipcoordinates)):
                 if (m!=item):
                     print('pOne',pOne)
                     pTwo = shipcoordinates[item]
                     print('pTwo',pTwo )
                     coordDist = round(distance(pOne,pTwo),2)
                     print('coordDist',coordDist )
                     radius.append(coordDist)
            effdist=decimal.Decimal(min(radius)).quantize(decimal.Decimal(".01"))
            count = 0
            diam=effdist*2
            print ('effdist',effdist)
            print ('diam',diam)
            for r in radius[0:]:
                        if (r <= diam): 
                           print(r)
                           count = count + 1
            output.append((effdist,count))
    for item in output:
        print  (item[0]," ".join(map(str, item[1:])))

    
main()

# %%
#from scipy.spatial.distance import pdist
import math
import decimal
from itertools import repeat
def truncate(number, digits) -> float:
    stepper = pow(10.0, digits)
    return math.trunc(stepper * number) / stepper
def distance(p1,p2):
    x1,y1=p1
    x2,y2=p2
    return math.hypot(x2-x1,y2-y1)
def main():
    testcases=int(input())
    output=[]
    #print(testcases)
    for i in range(0, testcases):
        L=int(input())
        #print (L)
        shipcoordinates=[]
        for j in range(0, L):
            x = list(map(int, input().split()))
            shipcoordinates.append(x)
        for m in range(0,len(shipcoordinates)):
            pOne = shipcoordinates[m]
            radius=[]
            
            for item in range(0,len(shipcoordinates)):
                 if (m!=item):
                     print('pOne',pOne)
                     pTwo = shipcoordinates[item]
                     print('pTwo',pTwo )
                     coordDist = truncate(distance(pOne,pTwo),2)
                     print('coordDist',coordDist )
                     radius.append(coordDist)
            effdist=decimal.Decimal(min(radius)).quantize(decimal.Decimal(".01"))
            count = 0
            diam=effdist*2
            print ('effdist',effdist)
            print ('diam',diam)
            for r in radius[0:]:
                        if (r <= diam): 
                           print(r)
                           count = count + 1
            output.append((effdist,count))
    for item in output:
        print  (item[0]," ".join(map(str, item[1:])))

    
main()
